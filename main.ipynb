# %%
from analyse import *

# %%
df
# Out:
#                     Cat                                            chambre  \
# 6   TRANSFORMATIONS-R+0                               HALL ENTREE - BUREAU
# 2   TRANSFORMATIONS-R+0                                        cuisine_sam
# 3   TRANSFORMATIONS-R+0                                        cuisine_sam
# 14  TRANSFORMATIONS-R+1                                         CHAMBRE 02
# 16  TRANSFORMATIONS-R+1                                         CHAMBRE 01
# 5   TRANSFORMATIONS-R+0                                        cuisine_sam
# 15  TRANSFORMATIONS-R+1                                   SALLE DE DOUCHES
# 10  TRANSFORMATIONS-R+1                                         CHAMBRE 03
# 11  TRANSFORMATIONS-R+1                                          HALL NUIT
# 7   TRANSFORMATIONS-R+0                               HALL ENTREE - BUREAU
# 4   TRANSFORMATIONS-R+0                                        cuisine_sam
# ...

# %%
df_r0
# Out:
#                    Cat               chambre  \
# 2  TRANSFORMATIONS-R+0           cuisine_sam
# 3  TRANSFORMATIONS-R+0           cuisine_sam
# 4  TRANSFORMATIONS-R+0           cuisine_sam
# 5  TRANSFORMATIONS-R+0           cuisine_sam
# 6  TRANSFORMATIONS-R+0  HALL ENTREE - BUREAU
# 7  TRANSFORMATIONS-R+0  HALL ENTREE - BUREAU
# 8  TRANSFORMATIONS-R+0  HALL ENTREE - BUREAU
#
#                                          description  Live Project  \
# 2                Agrandissement de baie pour ME 0.10       6693.00
# 3                 Agrandissement de baie pour ME 0.9       5175.00
# 4  Elargissement baie existante entre les deux pi...       2875.00
# 5     Création baie entre les deux pièces (côté rue)       2098.75
# 6                      Création de baie pour ME 0.8"       2098.75
# 7               Création baie entre les deux pièces"       2098.75
# 8                        Rehausse baie porte entrée"       2098.75
#
# ...

# %%
df_r1
# Out:
#                     Cat           chambre  \
# 9   TRANSFORMATIONS-R+1        CHAMBRE 03
# 10  TRANSFORMATIONS-R+1        CHAMBRE 03
# 11  TRANSFORMATIONS-R+1         HALL NUIT
# 12  TRANSFORMATIONS-R+1         HALL NUIT
# 13  TRANSFORMATIONS-R+1         HALL NUIT
# 14  TRANSFORMATIONS-R+1        CHAMBRE 02
# 15  TRANSFORMATIONS-R+1  SALLE DE DOUCHES
# 16  TRANSFORMATIONS-R+1        CHAMBRE 01
#
#                                           description  Live Project  \
# 9                       Création de baie pour ME 1.7"       2587.50
# 10  vers HALL NUIT - Création baie entre les deux ...       2098.75
# 11  Création baie entre les deux parties du HALL N...       2098.75
# 12       Création baie HALL NUIT vers SALLE DE BAINS"       2875.00
# 13  Elargissement baie existante entre HALL NUIT e...       1063.75
# 14          Elargissement baie existante pour ME 1.8"       2875.00
# 15                      Création de baie pour ME 1.9"       2098.75
# ...

# %%
first_plot()

# %%
second_plot()

# %%
third_plot()
